# %%
import pandas as pd

# %%
data = pd.read_csv('/content/recipes.csv') 
data.head()
# Out:
#    Unnamed: 0                  recipe_name prep_time cook_time     total_time  \
# 0           0     Apple-Cranberry Crostada       NaN       NaN            NaN
# 1           1    Apple Pie by Grandma Ople   30 mins     1 hrs  1 hrs 30 mins
# 2           2  Sarah's Homemade Applesauce   10 mins   15 mins        25 mins
# 3           3                  Apple Crisp   30 mins   45 mins  1 hrs 15 mins
# 4           4            Apple Pie Filling   20 mins   20 mins  2 hrs 40 mins
#
#    servings              yield  \
# 0         8  6 to 8 - servings
# 1         8       1 9-inch pie
# 2         4                NaN
# 3        12    1 9x13-inch pan
# 4        40      5 9-inch pies
#
#                                          ingredients  \
# 0  3 tablespoons butter, 2 pounds Granny Smith ap...
# 1  8 small Granny Smith apples, or as needed, ½ c...
# 2  4  apples - peeled, cored and chopped, ¾ cup w...
# 3  10 cups all-purpose apples, peeled, cored and ...
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'recipe_name', 'prep_time', 'cook_time', 'total_time',
#        'servings', 'yield', 'ingredients', 'directions', 'rating', 'url',
#        'cuisine_path', 'nutrition', 'timing', 'img_src'],
#       dtype='object')

# %%
data.iloc[0]
# Out:
# Unnamed: 0                                                      0
# recipe_name                              Apple-Cranberry Crostada
# prep_time                                                     NaN
# cook_time                                                     NaN
# total_time                                                    NaN
# servings                                                        8
# yield                                           6 to 8 - servings
# ingredients     3 tablespoons butter, 2 pounds Granny Smith ap...
# directions      Heat butter in a large skillet over medium-hig...
# rating                                                        4.4
# url             https://www.allrecipes.com/recipe/76931/apple-...
# cuisine_path      /Desserts/Fruit Desserts/Apple Dessert Recipes/
# nutrition       Total Fat 18g 23%, Saturated Fat 7g 34%, Chole...
# timing                      Servings: 8, Yield: 6 to 8 - servings
# ...

# %%
data = data.drop(['Unnamed: 0','servings','yield','rating','timing'], axis = 1)

# %%
data.iloc[0]
# Out:
# recipe_name                              Apple-Cranberry Crostada
# prep_time                                                     NaN
# cook_time                                                     NaN
# total_time                                                    NaN
# ingredients     3 tablespoons butter, 2 pounds Granny Smith ap...
# directions      Heat butter in a large skillet over medium-hig...
# url             https://www.allrecipes.com/recipe/76931/apple-...
# cuisine_path      /Desserts/Fruit Desserts/Apple Dessert Recipes/
# nutrition       Total Fat 18g 23%, Saturated Fat 7g 34%, Chole...
# img_src         https://www.allrecipes.com/thmb/Tf1wH73bfH6Oql...
# Name: 0, dtype: object

# %%
data = data.drop(['total_time','prep_time'], axis = 1)

# %%
data.iloc[0]
# Out:
# recipe_name                              Apple-Cranberry Crostada
# cook_time                                                     NaN
# ingredients     3 tablespoons butter, 2 pounds Granny Smith ap...
# directions      Heat butter in a large skillet over medium-hig...
# url             https://www.allrecipes.com/recipe/76931/apple-...
# cuisine_path      /Desserts/Fruit Desserts/Apple Dessert Recipes/
# nutrition       Total Fat 18g 23%, Saturated Fat 7g 34%, Chole...
# img_src         https://www.allrecipes.com/thmb/Tf1wH73bfH6Oql...
# Name: 0, dtype: object

# %%
data = data.drop(['url','cuisine_path'], axis = 1)

# %%
data.rename(columns = {'directions':'methode'}, inplace = True)

# %%
data.shape
# Out:
# (1090, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   recipe_name  1090 non-null   object
#  1   cook_time    782 non-null    object
#  2   ingredients  1090 non-null   object
#  3   methode      1090 non-null   object
#  4   nutrition    1090 non-null   object
#  5   img_src      1090 non-null   object
# dtypes: object(6)
# memory usage: 51.2+ KB

# %%
data.describe()
# Out:
#                   recipe_name cook_time  \
# count                    1090       782
# unique                    961        58
# top     Apple-Cranberry Crisp     1 hrs
# freq                        5        86
#
#                                               ingredients  \
# count                                                1090
# unique                                                961
# top     2 pounds Granny Smith apples - peeled, cored a...
# freq                                                    5
#
#                                                   methode  \
# count                                                1090
# unique                                                961
# top     Preheat the oven to 375 degrees F (190 degrees...
# freq                                                    5
#
#                                                 nutrition  \
# count                                                1090
# ...

# %%
cols = ["cook_time"]
data[cols]=data[cols].fillna(data.mode().iloc[0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   recipe_name  1090 non-null   object
#  1   cook_time    1090 non-null   object
#  2   ingredients  1090 non-null   object
#  3   methode      1090 non-null   object
#  4   nutrition    1090 non-null   object
#  5   img_src      1090 non-null   object
# dtypes: object(6)
# memory usage: 51.2+ KB

# %%
data2 = pd.read_csv('/content/test_recipes.csv')
data2
# Out:
#     Row                                               Name Prep Time  \
# 0     0                  Indian Chicken Curry (Murgh Kari)   20 mins
# 1     1                                   Chicken Stir-Fry   20 mins
# 2     2                                          Jambalaya   20 mins
# 3     3                                      Chicken Katsu   10 mins
# 4     4                       Simple Baked Chicken Breasts   10 mins
# 5     5                                    Chicken Marsala   10 mins
# 6     6                      Baked Garlic Parmesan Chicken   15 mins
# 7     7                               Asian Orange Chicken   20 mins
# 8     8                                Chicken Quesadillas   20 mins
# 9     9                                Chicken Cordon Bleu   10 mins
# 10   10                  Slow Cooker Chicken and Dumplings   10 mins
# 11   11                                        Easy Paella   30 mins
# 12   12                    Air Fryer Frozen Chicken Strips    5 mins
# ...

# %%
data.to_csv('food_data.csv')
